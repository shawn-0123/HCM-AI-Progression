# %% [markdown]
# # Submission
#
# Merges the two prediction files written by `01_severity_model.ipynb` and
# `02_mace_model.ipynb`. Run both of those first.

# %%
import pandas as pd

pred_df_severity = pd.read_csv("pred_severity.csv")
pred_df_mace = pd.read_csv("pred_mace.csv")

# %% [markdown]
# ## Merge

# %%
cardi5 = pd.merge(pred_df_mace, pred_df_severity, on='trustii_id')
#cardi5.to_csv('cardi5.csv', index=False)

# %%
cardi5
# Out:
#      trustii_id  OUTCOME MACE  OUTCOME SEVERITY
# 0             1             0          0.196824
# 1             2             2          0.290172
# 2             3             0          0.247374
# 3             4             0          0.236243
# 4             5             0          0.270367
# ..          ...           ...               ...
# 144         145             0          0.266493
# 145         146             0          0.196824
# 146         147             2          0.303974
# 147         148             0          0.244773
# 148         149             0          0.312373
#
# [149 rows x 3 columns]
